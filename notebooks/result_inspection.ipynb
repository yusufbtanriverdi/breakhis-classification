# %%
import pandas as pd

df = pd.read_csv("../classifiers/results/40X_lbp.csv")

df
# Out:
#                                           Unnamed: 0  train_accuracy
# 0                KNeighborsClassifier(n_neighbors=3)        0.893266  \
# 1                      SVC(C=0.025, kernel='linear')        0.744269
# 2                                  SVC(C=1, gamma=2)        0.950573
# 3  GaussianProcessClassifier(kernel=1**2 * RBF(le...        0.864613
# 4                DecisionTreeClassifier(max_depth=5)        0.782235
# 5  RandomForestClassifier(max_depth=5, max_featur...        0.773639
# 6              MLPClassifier(alpha=1, max_iter=1000)        0.787966
# 7                               AdaBoostClassifier()        0.799427
# 8                                       GaussianNB()        0.727794
# 9                    QuadraticDiscriminantAnalysis()        0.755014
#
#    train_roc_auc  train_ap    train_mapr  train_f1  train_r2  test_accuracy
# 0       0.865018  0.894340  2.967988e+14  0.923707  0.503669       0.741235  \
# ...

# %%
import pandas as pd

df = pd.read_csv("../classifiers/results/lbp_40Xbinary.csv")

df
# Out:
#                                           Unnamed: 0  train_accuracy
# 0                KNeighborsClassifier(n_neighbors=3)        0.893266  \
# 1                      SVC(C=0.025, kernel='linear')        0.734957
# 2                                  SVC(C=1, gamma=2)        0.940544
# 3  GaussianProcessClassifier(kernel=1**2 * RBF(le...        0.857450
# 4                DecisionTreeClassifier(max_depth=5)        0.779370
# 5  RandomForestClassifier(max_depth=5, max_featur...        0.770774
# 6              MLPClassifier(alpha=1, max_iter=1000)        0.779370
# 7                               AdaBoostClassifier()        0.788682
# 8                                       GaussianNB()        0.727077
# 9                    QuadraticDiscriminantAnalysis()        0.755014
#
#    train_roc_auc  train_ap    train_mapr  train_f1  train_r2  test_accuracy
# 0       0.861904  0.891651  3.129292e+14  0.924096  0.503669       0.779633  \
# ...
